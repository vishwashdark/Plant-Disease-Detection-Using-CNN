# %%
from tkinter import *

# Create object
root = Tk()

# Adjust size
root.geometry("1000x1000")
root.configure(bg="green")

# Add image file
bg = PhotoImage(file="C:/Users/sharm/OneDrive/Desktop/image.png")

# Create Canvas
canvas1 = Canvas(root, width=root.winfo_screenwidth(), height=root.winfo_screenheight(),bg='light green')
canvas1.pack(fill="both", expand=True)

# Display image
canvas1.create_image(220, 50, image=bg, anchor="nw")

# Add Text
canvas1.create_text(850, 30, text="PLANT DISEASE DETECTION", font=('Times', 24))

def open_page2():
    root.destroy()
    import tkinter as tk
    import numpy as np
    from tkinter import filedialog
    from tkinter.filedialog import askopenfile
    from PIL import Image, ImageTk
    from keras.models import load_model
    from keras.preprocessing import image
    from keras.applications.vgg16 import preprocess_input
    from tensorflow.keras.preprocessing import image
    import numpy as np
    import os
    import numpy as np
    import tensorflow as tf
    from tensorflow import keras
    my_w = tk.Tk()
    my_w.geometry("1200x600")  # Size of the window 
    my_w.title('KASHMIRI APPLE LEAF DISEASE DETECTION')
    my_font1=("Helvacita", 18, 'bold')
    l1 = tk.Label(my_w,text='Add leaf Image',height=10,width=80,font=my_font1)  
    l1.grid(row=1,column=1)
    b1 = tk.Button(my_w, text='Upload File',  width=20,command = lambda:upload_file())
    b1.grid(row=2,column=1) 
    def upload_file():
        global img
        f_types = [('Jpg Files', '*.jpg'),("JPEG Files" ,"*.jpeg")]
        filename = filedialog.askopenfilename(filetypes=f_types)
        img = ImageTk.PhotoImage(file=filename)
        img = ImageTk.PhotoImage(Image.open(filename))
        print(filename)
        
        model = keras.models.load_model("C:/Users/sharm/OneDrive/Desktop/BDA_Project/Rice_Leaf_model")
        rot=1
        healthy=1
        for filename in os.listdir(directory_path):
            if filename.endswith(".jpg.jpeg") or filename.endswith(".jpg") or filename.endswith(".JPG"):
                image_path = os.path.join(directory_path, filename)
                print(image_path)
                image = keras.preprocessing.image.load_img(image_path, target_size=(64, 64))
                input_arr = keras.preprocessing.image.img_to_array(image)
                input_arr = np.array([input_arr])  # Convert single image to a batch
                input_arr = input_arr / 255.0  # Normalize pixel values
                predictions = model.predict(input_arr)

                if predictions[0] > 0.005:
                    label = "Healthy Leaf"
                    print("Pneumonia")
                    a=tk.Label(my_w,text="Leaf Report")
                    a.grid(columnspan = 3,column=0,row=3)
                    inst=tk.Label(my_w,text="Healthy Leaf")
                    inst.grid(columnspan = 3,column=0,row=4)
                else:
                    print("Normal")
                    a=tk.Label(my_w,text="Rotten Leaf")
                    a.grid(columnspan = 3,column=0,row=3)
                    inst=tk.Label(my_w,text="    Normal    ")
                    inst.grid(columnspan= 3,column=0,row=4)

    my_w.mainloop()
    # code to open page 2
    pass
    directory_path = 'C:/Users/sharm/OneDrive/Desktop/BDA_Project/APPLE_DISEASE_DATASET/HEALTHY LEAVES'
    upload_file(directory_path)
    
 
# Create Buttons
button1 = Button( root, text = "Apple",bg="RED",font=('Arial Bold',16),height=2,width=10,command=open_page2)
button3 = Button( root, text = "Cotton",bg="cyan",font=('Arial Bold',16),height=2,width=10)
button2 = Button( root, text = "Rice",bg="PINK",font=('Arial Bold',16),height=2,width=10)

# Display Buttons
button1_canvas = canvas1.create_window( 400, 730,
									anchor = "c",
									window = button1)

button2_canvas = canvas1.create_window( 800, 730,
									anchor = "c",
									window = button2)

button3_canvas = canvas1.create_window( 1200, 730, anchor = "c",
									window = button3)

# Execute tkinter
root.mainloop()
# Out:
# D:/Cotton Disease/val/fresh cotton leaf/d (9)_iaip.jpg
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\sharm\AppData\Local\Temp\ipykernel_8796\3167141440.py", line 45, in <lambda>
#     b1 = tk.Button(my_w, text='Upload File',  width=20,command = lambda:upload_file())
#                                                                         ^^^^^^^^^^^^^
#   File "C:\Users\sharm\AppData\Local\Temp\ipykernel_8796\3167141440.py", line 55, in upload_file
#     model = keras.models.load_model("C:/Users/sharm/OneDrive/Desktop/BDA_Project/Rice_Leaf_model")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\saving\saving_api.py", line 212, in load_model
#     return legacy_sm_saving_lib.load_model(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\saving\legacy\save.py", line 230, in load_model
#     raise IOError(
# OSError: No file or directory found at C:/Users/sharm/OneDrive/Desktop/BDA_Project/Rice_Leaf_model
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\sharm\AppData\Local\Temp\ipykernel_8796\3167141440.py", line 86, in open_page2
#     upload_file(directory_path)
# TypeError: open_page2.<locals>.upload_file() takes 0 positional arguments but 1 was given

# %%
from tkinter import *

# Create object
root = Tk()

# Adjust size
root.geometry("1000x1000")
root.configure(bg="green")

# Add image file
bg = PhotoImage(file="C:/Users/sharm/OneDrive/Desktop/image1.png")

# Create Canvas
canvas1 = Canvas(root, width=root.winfo_screenwidth(), height=root.winfo_screenheight(), bg='light green')
canvas1.pack(fill="both", expand=True)

# Display image
canvas1.create_image(220, 50, image=bg, anchor="nw")

# Add Text
canvas1.create_text(850, 30, text="PLANT DISEASE DETECTION", font=('Times', 24))

def open_page2():
    root.destroy()
    # Your page 2 code here
    pass

# Create Buttons
button1 = Button(root, text="Apple", bg="RED", font=('Arial Bold', 16), height=2, width=10, command=open_page2)
button3 = Button(root, text="Cotton", bg="cyan", font=('Arial Bold', 16), height=2, width=10)

# Display Buttons
button1_canvas = canvas1.create_window(400, 730, anchor="c", window=button1)
button3_canvas = canvas1.create_window(1200, 730, anchor="c", window=button3)

# Execute tkinter
root.mainloop()
